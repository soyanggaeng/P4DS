# %%
from pymongo import MongoClient

# %%
client = MongoClient('mongodb://localhost:27017/')

# %%
db = client['sotube']

# %%
user = db.channel_info.find_one({'title' : "유소나"}, {'_id' : 0})

# %%
user['stat']
# Out:
# [{'searchDate': '2023-05-19',
#   'channelId': 'UCxeWKVovE_mKNRCwAlpL87A',
#   'videoCount': 777,
#   'viewCount': 209078428,
#   'dailyViewCount': 250111,
#   'subscriberCount': 639000,
#   'likesPerViewCount': 0.012828039360245975,
#   '__typename': 'ChannelStat'},
#  {'searchDate': '2023-05-18',
#   'channelId': 'UCxeWKVovE_mKNRCwAlpL87A',
#   'videoCount': 777,
#   'viewCount': 208828317,
#   'dailyViewCount': 239598,
#   'subscriberCount': 639000,
#   'likesPerViewCount': 0.012599987961692432,
#   '__typename': 'ChannelStat'},
#  {'searchDate': '2023-05-17',
#   'channelId': 'UCxeWKVovE_mKNRCwAlpL87A',
#   'videoCount': 776,
#   'viewCount': 208588719,
#   'dailyViewCount': 339950,
#   'subscriberCount': 638000,
#   'likesPerViewCount': 0.012463079512485837,
#   '__typename': 'ChannelStat'},
#  {'searchDate': '2023-05-16',
#   'channelId': 'UCxeWKVovE_mKNRCwAlpL87A',
#   'videoCount': 776,
#   'viewCount': 208248769,
#   'dailyViewCount': 297927,
#   'subscriberCount': 638000,
# ...
